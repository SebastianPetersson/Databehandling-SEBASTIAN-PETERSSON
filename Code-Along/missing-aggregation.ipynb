# %% [markdown]
# # Missing data techniques

# %%
import numpy as np
import pandas as pd


random_matrix = np.random.randint(1,10, (10,10))
index = np.random.choice(random_matrix.size, 10, replace=False)
print(f"index: {index}")
random_matrix
print(f"Flattens the matrix: {random_matrix.ravel()}") #Även flatten funkar men har lite andra användningsområden

random_matrix = random_matrix * 1.0
random_matrix.ravel()[index] = None
print(random_matrix)
# Out:
# index: [64 52 30 92 20 38 28 40 21  7]
# Flattens the matrix: [1 1 2 2 2 9 4 4 9 3 5 9 6 8 1 2 5 8 9 1 1 3 8 9 1 3 6 7 7 5 4 8 4 4 4 6 3
#  1 4 2 8 7 1 9 9 5 7 5 7 8 8 1 9 9 2 9 3 1 9 3 7 6 8 1 1 5 2 2 3 6 7 7 5 2
#  4 5 6 3 8 9 2 8 7 5 4 7 5 3 9 7 1 3 7 2 1 8 5 2 2 9]
# [[ 1.  1.  2.  2.  2.  9.  4. nan  9.  3.]
#  [ 5.  9.  6.  8.  1.  2.  5.  8.  9.  1.]
#  [nan nan  8.  9.  1.  3.  6.  7. nan  5.]
#  [nan  8.  4.  4.  4.  6.  3.  1. nan  2.]
#  [nan  7.  1.  9.  9.  5.  7.  5.  7.  8.]
#  [ 8.  1. nan  9.  2.  9.  3.  1.  9.  3.]
#  [ 7.  6.  8.  1. nan  5.  2.  2.  3.  6.]
#  [ 7.  7.  5.  2.  4.  5.  6.  3.  8.  9.]
#  [ 2.  8.  7.  5.  4.  7.  5.  3.  9.  7.]
#  [ 1.  3. nan  2.  1.  8.  5.  2.  2.  9.]]

# %%
scores = pd.DataFrame(random_matrix, 
                      index = [f"Player {i}" for i in range(1, n+1)],
                      columns = [f"Round {1}" for i in range (1, n+1)]
                      )

scores
# Out:
#           Round 1  Round 1  Round 1  Round 1  Round 1  Round 1  Round 1  \
# Player 1      2.0      8.0      9.0      2.0      3.0      5.0      NaN
# Player 2      7.0      5.0      9.0      2.0      6.0      6.0      9.0
# Player 3      5.0      NaN      7.0      8.0      1.0      7.0      8.0
# Player 4      6.0      7.0      9.0      9.0      9.0      4.0      4.0
# Player 5      4.0      4.0      2.0      9.0      5.0      NaN      1.0
# Player 6      NaN      8.0      8.0      NaN      1.0      4.0      8.0
# Player 7      8.0      7.0      5.0      NaN      1.0      2.0      3.0
# Player 8      NaN      9.0      NaN      1.0      9.0      NaN      4.0
#
#           Round 1
# Player 1      4.0
# Player 2      3.0
# Player 3      4.0
# Player 4      6.0
# Player 5      6.0
# Player 6      3.0
# Player 7      4.0
# Player 8      NaN

# %% [markdown]
# None = Python
# NaN = Not a Number - numpy
# NA = Pandas
#
# Pandas behandlar NaN och None typ likadant
#
# isnull()
# notnull()
# dropna()
# fillna()

# %%
scores.fillna(0)
# Out:
#           Round 1  Round 1  Round 1  Round 1  Round 1  Round 1  Round 1  \
# Player 1      2.0      8.0      9.0      2.0      3.0      5.0      0.0
# Player 2      7.0      5.0      9.0      2.0      6.0      6.0      9.0
# Player 3      5.0      0.0      7.0      8.0      1.0      7.0      8.0
# Player 4      6.0      7.0      9.0      9.0      9.0      4.0      4.0
# Player 5      4.0      4.0      2.0      9.0      5.0      0.0      1.0
# Player 6      0.0      8.0      8.0      0.0      1.0      4.0      8.0
# Player 7      8.0      7.0      5.0      0.0      1.0      2.0      3.0
# Player 8      0.0      9.0      0.0      1.0      9.0      0.0      4.0
#
#           Round 1
# Player 1      4.0
# Player 2      3.0
# Player 3      4.0
# Player 4      6.0
# Player 5      6.0
# Player 6      3.0
# Player 7      4.0
# Player 8      0.0

# %%
scores.dropna()
# Out:
#           Round 1  Round 1  Round 1  Round 1  Round 1  Round 1  Round 1  \
# Player 2      7.0      5.0      9.0      2.0      6.0      6.0      9.0
# Player 4      6.0      7.0      9.0      9.0      9.0      4.0      4.0
#
#           Round 1
# Player 2      3.0
# Player 4      6.0

# %%
scores.dropna(axis='columns')
# Out:
#           Round 1
# Player 1      3.0
# Player 2      6.0
# Player 3      1.0
# Player 4      9.0
# Player 5      5.0
# Player 6      1.0
# Player 7      1.0
# Player 8      9.0

# %%
scores.isnull()
# Out:
#           Round 1  Round 1  Round 1  Round 1  Round 1  Round 1  Round 1  \
# Player 1    False    False    False    False    False    False     True
# Player 2    False    False    False    False    False    False    False
# Player 3    False     True    False    False    False    False    False
# Player 4    False    False    False    False    False    False    False
# Player 5    False    False    False    False    False     True    False
# Player 6     True    False    False     True    False    False    False
# Player 7    False    False    False     True    False    False    False
# Player 8     True    False     True    False    False     True    False
#
#           Round 1
# Player 1    False
# Player 2    False
# Player 3    False
# Player 4    False
# Player 5    False
# Player 6    False
# Player 7    False
# Player 8     True

# %%
scores.notnull()
# Out:
#           Round 1  Round 1  Round 1  Round 1  Round 1  Round 1  Round 1  \
# Player 1     True     True     True     True     True     True    False
# Player 2     True     True     True     True     True     True     True
# Player 3     True    False     True     True     True     True     True
# Player 4     True     True     True     True     True     True     True
# Player 5     True     True     True     True     True    False     True
# Player 6    False     True     True    False     True     True     True
# Player 7     True     True     True    False     True     True     True
# Player 8    False     True    False     True     True    False     True
#
#           Round 1
# Player 1     True
# Player 2     True
# Player 3     True
# Player 4     True
# Player 5     True
# Player 6     True
# Player 7     True
# Player 8    False

# %% [markdown]
# # Missing data - strategy

# %%
import seaborn as sns
titanic = sns.load_dataset("titanic")
titanic.head(10)
nulls = titanic.isnull().sum()
nulls
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
sns.histplot(data=titanic, x = 'age', hue = 'sex', kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
median_male_age = titanic[titanic['sex'] == 'male']['age'].median()
median_female_age = titanic[titanic['sex'] == 'female']['age'].median()

print(f"Median male age : {median_male_age.astype(int)}")
print(f"Median female age : {median_female_age}")

titanic.loc[titanic['sex'] == 'male', 'age'] = titanic.loc[titanic['sex'] == 'male', 'age'].fillna(median_male_age)
titanic.loc[titanic['age']== 29, 'sex'].value_counts()
# Out:
# Median male age : 29
# Median female age : 27.0
# sex
# male      137
# female      7
# Name: count, dtype: int64

# %%
print(titanic.isnull().sum().loc['age'])
titanic.loc[titanic['age'].isnull(), 'sex'].value_counts()
# Out:
# 53
# sex
# female    53
# Name: count, dtype: int64

# %%
titanic['age'] = titanic['age'].fillna(median_female_age)
titanic.isnull().sum().sex
# Out:
# np.int64(0)

# %%
sns.histplot(data= titanic, x = 'age', kde = True, hue = 'sex')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# # Aggregations and groupby

# %%
survivors = titanic.groupby('sex').mean(numeric_only=True)[['survived', 'age']]
for i in survivors.index:
    survived_percentage = survivors.loc[i, 'survived'] * 100
    print(f"Percentage survived {i}: {survived_percentage:.1f} %.")
    print(f'Mean age of survived {i}: {survivors.loc[i, 'age']:.1f}')
# Out:
# Percentage survived female: 74.2 %.
# Mean age of survived female: 27.8
# Percentage survived male: 18.9 %.
# Mean age of survived male: 30.4

# %%
titanic.groupby('class')[['age','fare']].max()
# Out:
# C:\Users\Sebastian!\AppData\Local\Temp\ipykernel_11652\2294669943.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   titanic.groupby('class')[['age','fare']].max()
#          age      fare
# class
# First   80.0  512.3292
# Second  70.0   73.5000
# Third   74.0   69.5500

# %%
survived_class = titanic.groupby(['survived', 'pclass']).count()
survived_class = survived_class.reset_index()
ax = sns.barplot(data=survived_class, x = 'pclass', y = 'sex', hue = 'survived', palette='rocket')
ax.set(ylabel ='count', title ='survival count in titanic vs class')
# Out:
# [Text(0, 0.5, 'count'), Text(0.5, 1.0, 'survival count in titanic vs class')]

# %%
display(survived_class)
# Out:
#    survived  pclass  sex  age  sibsp  parch  fare  embarked  class  who  \
# 0         0       1   80   80     80     80    80        80     80   80
# 1         0       2   97   97     97     97    97        97     97   97
# 2         0       3  372  372    372    372   372       372    372  372
# 3         1       1  136  136    136    136   136       134    136  136
# 4         1       2   87   87     87     87    87        87     87   87
# 5         1       3  119  119    119    119   119       119    119  119
#
#    adult_male  deck  embark_town  alive  alone
# 0          80    58           80     80     80
# 1          97     3           97     97     97
# 2         372     6          372    372    372
# 3         136   117          134    136    136
# 4          87    13           87     87     87
# 5         119     6          119    119    119
